# %%
import pyarrow.parquet as pq

data = pq.read_table("data\data_1.parquet")

# %%
df = data.to_pandas()

# %%
df
# Out:
#                                              instruction  \
# 0      Create a function to calculate the sum of a se...
# 1      Generate a Python code for crawling a website ...
# 2      Create a Python list comprehension to get the ...
# 3       Generate a python script to perform this action.
# 4      Write a python script to generates random numb...
# ...                                                  ...
# 18607  Generate a loop in Python which iterates throu...
# 18608  Can you design a function in Python to sort a ...
# 18609  Generate a Python function to search an array ...
# 18610  Develop an HTTP API in Python to retrieve the ...
# 18611  Create a classification algorithm in Python to...
#
#                                                    input  \
# 0                                        [1, 2, 3, 4, 5]
# 1      website: www.example.com \ndata to crawl: phon...
# 2
# 3      Given a string, remove all the consecutive dup...
# 4
# ...                                                  ...
# 18607
# 18608           tuples = [("b", 0), ("a", 1), ("c", -1)]
# 18609            Array = [1, 5, 10, 15, 20], Target = 15
# 18610
# 18611
#
#                                                   output  \
# 0      # Python code\ndef sum_sequence(sequence):\n  ...
# 1      import requests\nimport re\n\ndef crawl_websit...
# 2                     [x*x for x in [1, 2, 3, 5, 8, 13]]
# 3      def remove_duplicates(string): \n    result = ...
# 4      def generate_random_divisible_number():\n    i...
# ...                                                  ...
# 18607     for value in list_of_values:\n    print(value)
# 18608  def sort_tuple(tuples):\n    # sort by 2nd ite...
# 18609  def search(array, target):\n # Iterate over ar...
# 18610  import requests\nfrom bs4 import BeautifulSoup...
# 18611  # Import Python libraries\nimport numpy as np\...
#
#                                                   prompt
# 0      Below is an instruction that describes a task....
# 1      Below is an instruction that describes a task....
# 2      Below is an instruction that describes a task....
# 3      Below is an instruction that describes a task....
# 4      Below is an instruction that describes a task....
# ...                                                  ...
# 18607  Below is an instruction that describes a task....
# 18608  Below is an instruction that describes a task....
# 18609  Below is an instruction that describes a task....
# 18610  Below is an instruction that describes a task....
# 18611  Below is an instruction that describes a task....
#
# [18612 rows x 4 columns]

# %%
df.to_csv("python_code_instructions.csv")

# %%
from pyarrow import json
table = json.read_json("data\leetcodecomplete.jsonl")

# %%
df = table.to_pandas()

# %%
df
# Out:
#                                            instruction  \
# 0     Create a solution in python for the input asked.
# 1     Create a solution in python for the input asked.
# 2     Create a solution in python for the input asked.
# 3     Create a solution in python for the input asked.
# 4     Create a solution in python for the input asked.
# ...                                                ...
# 2354  Create a solution in python for the input asked.
# 2355  Create a solution in python for the input asked.
# 2356  Create a solution in python for the input asked.
# 2357  Create a solution in python for the input asked.
# 2358  Create a solution in python for the input asked.
#
#                                                   input  \
# 0     The algorithm leverages a hash map (unordered_...
# 1     1. Initialize a dummy ListNode with a value of...
# 2     The algorithm uses a sliding window with two p...
# 3     1. Choose the smaller array as nums1 so that t...
# 4     1. Initialize `start` and `maxLength` for resu...
# ...                                                 ...
# 2354  The algorithm starts by creating an adjacency ...
# 2355  The algorithm scans the string `s` twice. In t...
# 2356  The algorithm iterates through the input array...
# 2357  1. For each type of cheese, calculate the diff...
# 2358  1. Create a set from the `banned` positions fo...
#
#                                                  output  \
# 0     ```python\ndef twoSum(nums, target):\n    map ...
# 1     ```python\nclass ListNode:\n    def __init__(s...
# 2     ```python\ndef length_of_longest_substring(s: ...
# 3     ```python\ndef findMedianSortedArrays(nums1, n...
# 4     ```python\ndef longest_palindromic_substring(s...
# ...                                                 ...
# 2354  ```python\nfrom collections import deque\n\nde...
# 2355  ```python\ndef longestBalancedSubstring(s):\n ...
# 2356  ```python\ndef distinct_rows_from(nums):\n    ...
# 2357  ```python\ndef maxPoints(reward1, reward2, k):...
# 2358  ```python\ndef reach_position(n, p, banned, k)...
#
#                                                    text
# 0     Below is an instruction that describes a task,...
# 1     Below is an instruction that describes a task,...
# 2     Below is an instruction that describes a task,...
# 3     Below is an instruction that describes a task,...
# 4     Below is an instruction that describes a task,...
# ...                                                 ...
# 2354  Below is an instruction that describes a task,...
# 2355  Below is an instruction that describes a task,...
# 2356  Below is an instruction that describes a task,...
# 2357  Below is an instruction that describes a task,...
# 2358  Below is an instruction that describes a task,...
#
# [2359 rows x 4 columns]

# %%
df.to_csv("data_leetcode_problems.csv")

# %%
dfdfbdfbg
